# %%
orders = pd.read_excel('/content/temp data dictionary.xlsx')

# %% [markdown]
# # Orders Table

# %%
orders
# Out:
#                Column Name                 Data Type  Description/Notes  \
# 0                     asin                      text                NaN
# 1          audience_rating                      text                NaN
# 2                   author                      text                NaN
# 3                  binding                      text                NaN
# 4                 category                      text                NaN
# 5              contributor                      text                NaN
# 6           dimension_unit                      text                NaN
# 7                      ean                      text                NaN
# 8                    genre                      text                NaN
# 9                   height                   numeric                NaN
# 10        is_adult_product                   boolean                NaN
# 11               languages                      text                NaN
# ...
